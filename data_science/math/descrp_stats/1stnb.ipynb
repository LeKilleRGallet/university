# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('cars.csv')
df
# Out:
#       manufacturer_name  model_name transmission   color  odometer_value  \
# 0                Subaru     Outback    automatic  silver          190000
# 1                Subaru     Outback    automatic    blue          290000
# 2                Subaru    Forester    automatic     red          402000
# 3                Subaru     Impreza   mechanical    blue           10000
# 4                Subaru      Legacy    automatic   black          280000
# ...                 ...         ...          ...     ...             ...
# 38526          Chrysler         300    automatic  silver          290000
# 38527          Chrysler  PT Cruiser   mechanical    blue          321000
# 38528          Chrysler         300    automatic    blue          777957
# 38529          Chrysler  PT Cruiser   mechanical   black           20000
# 38530          Chrysler     Voyager    automatic  silver          297729
#
#        year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# ...

# %%
df.dtypes
# Out:
# manufacturer_name     object
# model_name            object
# transmission          object
# color                 object
# odometer_value         int64
# year_produced          int64
# engine_fuel           object
# engine_has_gas          bool
# engine_type           object
# engine_capacity      float64
# body_type             object
# has_warranty            bool
# state                 object
# drivetrain            object
# price_usd            float64
# is_exchangeable         bool
# location_region       object
# number_of_photos       int64
# up_counter             int64
# feature_0               bool
# feature_1               bool
# feature_2               bool
# feature_3               bool
# feature_4               bool
# feature_5               bool
# feature_6               bool
# feature_7               bool
# feature_8               bool
# feature_9               bool
# duration_listed        int64
# dtype: object

# %%
df.describe()
# Out:
#        odometer_value  year_produced  engine_capacity     price_usd  \
# count    38531.000000   38531.000000     38521.000000  38531.000000
# mean    248864.638447    2002.943734         2.055161   6639.971021
# std     136072.376530       8.065731         0.671178   6428.152018
# min          0.000000    1942.000000         0.200000      1.000000
# 25%     158000.000000    1998.000000         1.600000   2100.000000
# 50%     250000.000000    2003.000000         2.000000   4800.000000
# 75%     325000.000000    2009.000000         2.300000   8990.000000
# max    1000000.000000    2019.000000         8.000000  50000.000000
#
#        number_of_photos    up_counter  duration_listed
# count      38531.000000  38531.000000     38531.000000
# mean           9.649062     16.306091        80.577249
# std            6.093217     43.286933       112.826569
# min            1.000000      1.000000         0.000000
# 25%            5.000000      2.000000        23.000000
# ...

# %%
df['price_usd'].mean()
# Out:
# 6639.971021255613

# %%
df['price_usd'].median()
# Out:
# 4800.0

# %%
df['price_usd'].plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.displot(df, x='price_usd', hue='manufacturer_name')

# %%
sns.displot(df, x='price_usd', hue='engine_type', multiple='stack')

# %%
df.groupby('engine_type').count()
# Out:
#              manufacturer_name  model_name  transmission  color  \
# engine_type
# diesel                   12874       12874         12874  12874
# electric                    10          10            10     10
# gasoline                 25647       25647         25647  25647
#
#              odometer_value  year_produced  engine_fuel  engine_has_gas  \
# engine_type
# diesel                12874          12874        12874           12874
# electric                 10             10           10              10
# gasoline              25647          25647        25647           25647
#
#              engine_capacity  body_type  ...  feature_1  feature_2  feature_3  \
# engine_type                              ...
# diesel                 12874      12874  ...      12874      12874      12874
# electric                   0         10  ...         10         10         10
# gasoline               25647      25647  ...      25647      25647      25647
#
# ...

# %%
Q7_df=df[(df['manufacturer_name']=='Audi') & (df['model_name']=='Q7')]
Q7_df
# Out:
#       manufacturer_name model_name transmission   color  odometer_value  \
# 19515              Audi         Q7    automatic    grey          275000
# 19547              Audi         Q7    automatic   white          105000
# 19559              Audi         Q7    automatic   other          170000
# 19574              Audi         Q7    automatic   black          185000
# 19583              Audi         Q7    automatic   other          210000
# ...                 ...        ...          ...     ...             ...
# 21756              Audi         Q7    automatic  silver          200000
# 21812              Audi         Q7    automatic   black          276000
# 21873              Audi         Q7    automatic   black          273000
# 21900              Audi         Q7    automatic   white          283000
# 21942              Audi         Q7    automatic    grey          262000
#
#        year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# ...

# %%
sns.histplot(Q7_df, x='price_usd', hue='year_produced')
# Out:
# <AxesSubplot:xlabel='price_usd', ylabel='Count'>

# %%
df['model_name'].mode()
# Out:
# 0    Passat
# Name: model_name, dtype: object

# %%
df[df['model_name']=='Passat']
# Out:
#       manufacturer_name model_name transmission  color  odometer_value  \
# 15077        Volkswagen     Passat   mechanical   grey          215000
# 15078        Volkswagen     Passat   mechanical  white          500000
# 15082        Volkswagen     Passat   mechanical  green          316000
# 15083        Volkswagen     Passat   mechanical  black          285000
# 15084        Volkswagen     Passat   mechanical  black          375000
# ...                 ...        ...          ...    ...             ...
# 19297        Volkswagen     Passat   mechanical  black          270000
# 19298        Volkswagen     Passat   mechanical  other          210000
# 19301        Volkswagen     Passat   mechanical  other          270000
# 19303        Volkswagen     Passat   mechanical    red         1000000
# 19307        Volkswagen     Passat   mechanical  white          100000
#
#        year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# ...

# %%
sns.histplot(df[df['model_name']=='Passat'], x='price_usd', hue='year_produced')
# Out:
# <AxesSubplot:xlabel='price_usd', ylabel='Count'>

# %%
df[df['model_name']=='Passat'].describe()
# Out:
#        odometer_value  year_produced  engine_capacity     price_usd  \
# count     1423.000000    1423.000000      1423.000000   1423.000000
# mean    294548.590302    2000.494027         1.848138   5106.278454
# std     125430.340463       8.213471         0.213392   3870.245879
# min          1.000000    1980.000000         1.300000    200.000000
# 25%     218500.000000    1993.000000         1.800000   1900.000000
# 50%     298048.000000    2001.000000         1.800000   4250.000000
# 75%     355000.000000    2007.000000         2.000000   7200.000000
# max    1000000.000000    2018.000000         3.200000  24500.000000
#
#        number_of_photos   up_counter  duration_listed
# count       1423.000000  1423.000000      1423.000000
# mean           9.444132    12.599438        69.884751
# std            5.948401    25.047124        87.213840
# min            1.000000     1.000000         0.000000
# 25%            5.000000     2.000000        19.000000
# ...

# %%
df[df['model_name']=='Passat']['price_usd'].std()
# Out:
# 3870.2458790383357

# %%
df[df['model_name']=='Passat']['price_usd'].var()
# Out:
# 14978803.164213222

# %%
Q1, Q3 = df[df['model_name']=='Passat']['price_usd'].quantile([0.25, 0.75])
IQR = Q3 - Q1
IQR
# Out:
# 5300.0

# %%
minlimit = Q1 - 1.5*IQR
maxlimit = Q3 + 1.5*IQR
print(minlimit, maxlimit)
# Out:
# -6050.0 15150.0

# %%
sns.histplot(df[df['model_name']=='Passat'], x='price_usd')
# Out:
# <AxesSubplot:xlabel='price_usd', ylabel='Count'>

# %%
sns.distplot(df[df['model_name']=='Passat']['price_usd'])
# Out:
# <AxesSubplot:xlabel='price_usd', ylabel='Density'>

# %%
sns.boxplot(df[df['model_name']=='Passat']['price_usd'])
# Out:
# <AxesSubplot:xlabel='price_usd'>

# %%
passat_df = df[df['model_name']=='Passat']

# %%
sns.boxplot(x='engine_fuel', y='price_usd', data=passat_df)
# Out:
# <AxesSubplot:xlabel='engine_fuel', ylabel='price_usd'>
