# %% [markdown]
# ---
# Augusto Rico
# ---

# %% [markdown]
# # 1

# %%
library(tidyverse)
library(readxl)

# %%
df<-read.csv("Pokemon.csv")
df$Legendary<-as.logical(df$Legendary)
df
# Out:
#     id  Name                      Type.1   Type.2 Total HP  Attack Defense
# 1    1  Bulbasaur                 Grass    Poison 318   45   49     49
# 2    2  Ivysaur                   Grass    Poison 405   60   62     63
# 3    3  Venusaur                  Grass    Poison 525   80   82     83
# 4    3  VenusaurMega Venusaur     Grass    Poison 625   80  100    123
# 5    4  Charmander                Fire            309   39   52     43
# 6    5  Charmeleon                Fire            405   58   64     58
# 7    6  Charizard                 Fire     Flying 534   78   84     78
# 8    6  CharizardMega Charizard X Fire     Dragon 634   78  130    111
# 9    6  CharizardMega Charizard Y Fire     Flying 634   78  104     78
# 10   7  Squirtle                  Water           314   44   48     65
# 11   8  Wartortle                 Water           405   59   63     80
# 12   9  Blastoise                 Water           530   79   83    100
# ...

# %%
cat('the datatype of Name is: ',typeof(df$Name))
cat('\nthe datatype of HP is: ',typeof(df$HP))
cat('\nthe datatype of Attack is: ',typeof(df$Attack))
cat('\nthe datatype of Legendary is: ',typeof(df$Legendary))
# Out:
# the datatype of Name is:  character
# the datatype of HP is:  integer
# the datatype of Attack is:  integer
# the datatype of Legendary is:  logical

# %% [markdown]
# # 2

# %%
df_f100<-df[df$id<=100,]
df_f100
# Out:
#     id  Name                      Type.1   Type.2  Total HP  Attack Defense
# 1    1  Bulbasaur                 Grass    Poison  318   45   49     49
# 2    2  Ivysaur                   Grass    Poison  405   60   62     63
# 3    3  Venusaur                  Grass    Poison  525   80   82     83
# 4    3  VenusaurMega Venusaur     Grass    Poison  625   80  100    123
# 5    4  Charmander                Fire             309   39   52     43
# 6    5  Charmeleon                Fire             405   58   64     58
# 7    6  Charizard                 Fire     Flying  534   78   84     78
# 8    6  CharizardMega Charizard X Fire     Dragon  634   78  130    111
# 9    6  CharizardMega Charizard Y Fire     Flying  634   78  104     78
# 10   7  Squirtle                  Water            314   44   48     65
# 11   8  Wartortle                 Water            405   59   63     80
# 12   9  Blastoise                 Water            530   79   83    100
# ...

# %%
cat('the mean attack of the first 100 pokemon is: ', mean(df_f100$Attack), 'and the mean attack of all pokemon is: ', mean(df$Attack))
cat('\nthe mean defense of the first 100 pokemon is: ', mean(df_f100$Defense), 'and the mean defense of all pokemon is: ', mean(df$Defense))
cat('\nthe mean speed of the first 100 pokemon is: ', mean(df_f100$Speed), 'and the mean speed of all pokemon is: ', mean(df$Speed))
# Out:
# the mean attack of the first 100 pokemon is:  71.37615 and the mean attack of all pokemon is:  79.00125
# the mean defense of the first 100 pokemon is:  66.06422 and the mean defense of all pokemon is:  73.8425
# the mean speed of the first 100 pokemon is:  69.74312 and the mean speed of all pokemon is:  68.2775

# %% [markdown]
# los primeros 100 pokemon tienen un ataque menor que el promedio de todos los pokemon\
# los primeros 100 pokemon tienen una defensa menor que el promedio de todos los pokemon\
# los primeros 100 pokemon tienen una velocidad mayor no significa que el promedio de todos los pokemon

# %% [markdown]
# # 3

# %%
df %>% group_by(Type.1) %>% summarise(mean_attack=mean(Attack),mean_defense=mean(Defense),mean_speed=mean(Speed), Total=mean(Total), count=n())
# Out:
#    Type.1   mean_attack mean_defense mean_speed Total    count
# 1  Bug       70.97101    70.72464     61.68116  378.9275  69
# 2  Dark      88.38710    70.22581     76.16129  445.7419  31
# 3  Dragon   112.12500    86.37500     83.03125  550.5312  32
# 4  Electric  69.09091    66.29545     84.50000  443.4091  44
# 5  Fairy     61.52941    65.70588     48.58824  413.1765  17
# 6  Fighting  96.77778    65.92593     66.07407  416.4444  27
# 7  Fire      84.76923    67.76923     74.44231  458.0769  52
# 8  Flying    78.75000    66.25000    102.50000  485.0000   4
# 9  Ghost     73.78125    81.18750     64.34375  439.5625  32
# 10 Grass     73.21429    70.80000     61.92857  421.1429  70
# 11 Ground    95.75000    84.84375     63.90625  437.5000  32
# 12 Ice       72.75000    71.41667     63.45833  433.4583  24
# 13 Normal    73.46939    59.84694     71.55102  401.6837  98
# 14 Poison    74.67857    68.82143     63.57143  399.1429  28
# ...

# %% [markdown]
# # 4

# %%
df %>% group_by(Legendary) %>% summarise(Total=mean(Total), count=n())
# Out:
#   Legendary Total    count
# 1 FALSE     417.2136 735
# 2  TRUE     637.3846  65

# %% [markdown]
# los pokemon legendarios tienen hablidades en conjunto mas fuertes que los que no son legendarios, por lo que en promedio un enfrentamiento entre un pokemon legendario y uno no legendario, el pokemon legendario debe tener una mayor probabilidad de victoria

# %% [markdown]
# # 5

# %%
names(df)
# Out:
#  [1] "id"         "Name"       "Type.1"     "Type.2"     "Total"
#  [6] "HP"         "Attack"     "Defense"    "Sp..Atk"    "Sp..Def"
# [11] "Speed"      "Generation" "Legendary"

# %%
df<-df %>% mutate(Total_copy=Attack+Defense+Speed+HP+Sp..Atk+Sp..Def)
df
# Out:
#     id  Name                      Type.1   Type.2 Total HP  Attack Defense
# 1    1  Bulbasaur                 Grass    Poison 318   45   49     49
# 2    2  Ivysaur                   Grass    Poison 405   60   62     63
# 3    3  Venusaur                  Grass    Poison 525   80   82     83
# 4    3  VenusaurMega Venusaur     Grass    Poison 625   80  100    123
# 5    4  Charmander                Fire            309   39   52     43
# 6    5  Charmeleon                Fire            405   58   64     58
# 7    6  Charizard                 Fire     Flying 534   78   84     78
# 8    6  CharizardMega Charizard X Fire     Dragon 634   78  130    111
# 9    6  CharizardMega Charizard Y Fire     Flying 634   78  104     78
# 10   7  Squirtle                  Water           314   44   48     65
# 11   8  Wartortle                 Water           405   59   63     80
# 12   9  Blastoise                 Water           530   79   83    100
# ...

# %% [markdown]
# # Extra

# %%
df<-df %>% mutate(have_type.2=ifelse(Type.2=="",FALSE,TRUE))
df %>% group_by(have_type.2) %>% summarise(Total=mean(Total), count=n())
# Out:
#   have_type.2 Total    count
# 1 FALSE       412.0155 386
# 2  TRUE       456.6280 414

# %% [markdown]
# los pokemon con segunda habilidad son mas fuertes que los que no tienen segunda habilidad

# %%
df %>% group_by(Generation) %>% summarise(Total=mean(Total), count=n())
# Out:
#   Generation Total    count
# 1 1          426.8133 166
# 2 2          418.2830 106
# 3 3          436.2250 160
# 4 4          459.0165 121
# 5 5          434.9879 165
# 6 6          436.3780  82

# %% [markdown]
# los pokemon de la cuarta generacion son los mas fuertes de todos con una significativa diferencia

# %%
df %>% group_by(Legendary,Generation) %>% summarise(Total=mean(Total), count=n())
# Out:
# `summarise()` has grouped output by 'Legendary'. You can override using the
# `.groups` argument.
#    Legendary Generation Total    count
# 1  FALSE     1          417.9438 160
# 2  FALSE     2          408.2970 101
# 3  FALSE     3          409.2676 142
# 4  FALSE     4          437.8796 108
# 5  FALSE     5          416.6200 150
# 6  FALSE     6          414.0946  74
# 7   TRUE     1          663.3333   6
# 8   TRUE     2          620.0000   5
# 9   TRUE     3          648.8889  18
# 10  TRUE     4          634.6154  13
# 11  TRUE     5          618.6667  15
# 12  TRUE     6          642.5000   8

# %% [markdown]
# apesar de los pocos que hay la primera generacion es la que tiene los pokemon legendarios mas fuertes
