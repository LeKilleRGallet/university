# %%
df<-read.table('http://www.sthda.com/upload/boxplot_format.txt')
df
# Out:
#    V1    V2       V3
# 1  Nom   variable Group
# 2  IND1  10       A
# 3  IND2  7        A
# 4  IND3  20       A
# 5  IND4  14       A
# 6  IND5  14       A
# 7  IND6  12       A
# 8  IND7  10       A
# 9  IND8  23       A
# 10 IND9  17       A
# 11 IND10 20       A
# 12 IND11 14       A
# 13 IND12 13       A
# 14 IND13 11       B
# 15 IND14 17       B
# 16 IND15 21       B
# 17 IND16 11       B
# 18 IND17 16       B
# 19 IND18 14       B
# 20 IND19 17       B
# 21 IND20 17       B
# 22 IND21 19       B
# 23 IND22 21       B
# 24 IND23 7        B
# 25 IND24 13       B
# 26 IND25 0        C
# 27 IND26 1        C
# 28 IND27 7        C
# 29 IND28 2        C
# 30 IND29 3        C
# ⋮  ⋮     ⋮        ⋮
# 44 IND43 5        D
# 45 IND44 5        D
# 46 IND45 5        D
# 47 IND46 5        D
# 48 IND47 2        D
# 49 IND48 4        D
# 50 IND49 3        E
# 51 IND50 5        E
# 52 IND51 3        E
# 53 IND52 5        E
# 54 IND53 3        E
# 55 IND54 6        E
# 56 IND55 1        E
# ...

# %%
df2<-read.table('BASETXT (1).txt', sep=',', header=TRUE)
df2
# Out:
# Warning message in read.table("BASETXT (1).txt", sep = ",", header = TRUE):
# “incomplete final line found by readTableHeader on 'BASETXT (1).txt'”
#   EDAD GENERO NOMBRE  CIUDAD
# 1 21    F      JUANA   BOGOTA
# 2 23    M      CARLOS  BARRANQUILLA
# 3 45    M      DAVID   MEDELLIN
# 4 25    F      NICOL   POPAYAN

# %%
df3<-read.table('TOTALSACSV (1).csv', sep=',', header=TRUE)
df3
# Out:
#     DATE       TOTALSA
# 1   1976-01-01 12.814
# 2   1976-02-01 13.340
# 3   1976-03-01 13.378
# 4   1976-04-01 13.223
# 5   1976-05-01 12.962
# 6   1976-06-01 13.051
# 7   1976-07-01 13.466
# 8   1976-08-01 12.953
# 9   1976-09-01 13.610
# 10  1976-10-01 12.823
# 11  1976-11-01 13.332
# 12  1976-12-01 14.527
# 13  1977-01-01 14.396
# 14  1977-02-01 14.709
# 15  1977-03-01 15.170
# 16  1977-04-01 15.135
# 17  1977-05-01 14.984
# 18  1977-06-01 14.952
# 19  1977-07-01 14.641
# 20  1977-08-01 14.859
# 21  1977-09-01 14.650
# 22  1977-10-01 14.900
# 23  1977-11-01 14.799
# 24  1977-12-01 15.175
# 25  1978-01-01 13.704
# 26  1978-02-01 14.363
# 27  1978-03-01 15.166
# 28  1978-04-01 16.198
# 29  1978-05-01 16.298
# 30  1978-06-01 16.348
# ⋮   ⋮          ⋮
# 512 2018-08-01 17.324
# 513 2018-09-01 17.812
# 514 2018-10-01 18.155
# 515 2018-11-01 17.854
# 516 2018-12-01 17.962
# 517 2019-01-01 17.312
# 518 2019-02-01 17.107
# 519 2019-03-01 17.838
# 520 2019-04-01 17.164
# ...

# %%
library(readxl)
df4<-read_excel('Colombia_Cobb_Douglas (1).xlsx',1)
df4
# Out:
#    Country  Id  Year Quality Pop(000s) N        Fertility Birth  Mortality
# 1  Colombia COL 1963 C       17546.02   4902182 6.731     43.689 11.246
# 2  Colombia COL 1964 C       18090.00   5027611 6.661     43.246 10.966
# 3  Colombia COL 1965 C       18646.17   5154814 6.559     42.672 10.691
# 4  Colombia COL 1966 C       19201.73   5280213 6.422     41.923 10.416
# 5  Colombia COL 1967 C       19764.03   5405825 6.250     41.002 10.145
# 6  Colombia COL 1968 C       20321.67   5528519 6.050     39.938  9.880
# 7  Colombia COL 1969 C       20869.14   5646826 5.830     38.769  9.620
# 8  Colombia COL 1970 C       21429.66   5767036 5.599     37.570  9.365
# 9  Colombia COL 1971 C       21992.58   5968027 5.370     36.431  9.118
# 10 Colombia COL 1972 C       22542.89   6168101 5.153     35.423  8.880
# 11 Colombia COL 1973 C       23069.23   6364041 4.956     34.591  8.653
# 12 Colombia COL 1974 C       23598.13   6563062 4.782     33.948  8.433
# ...

# %%
library(wooldridge)
data('discrim')
View(discrim)
# Out:
#     psoda pfries pentree wagest nmgrs nregs hrsopen emp   psoda2 pfries2 ⋯
# 1   1.12  1.06   1.02    4.25   3      5    16.0    27.5  1.11   1.11    ⋯
# 2   1.06  0.91   0.95    4.75   3      3    16.5    21.5  1.05   0.89    ⋯
# 3   1.06  0.91   0.98    4.25   3      5    18.0    30.0  1.05   0.94    ⋯
# 4   1.12  1.02   1.06    5.00   4      5    16.0    27.5  1.15   1.05    ⋯
# 5   1.12    NA   0.49    5.00   3      3    16.0     5.0  1.04   1.01    ⋯
# 6   1.06  0.95   1.01    4.25   4      4    15.0    17.5  1.05   0.94    ⋯
# 7   1.17  0.95   0.95    4.65   3      2    16.0    22.5  1.05   0.94    ⋯
# 8   1.17  1.02   1.06    4.50   3      5    17.0    18.5  1.11   1.06    ⋯
# 9   1.18  1.02   1.06      NA   4      4    17.0    17.0  1.10   1.01    ⋯
# 10  1.17  1.12   1.02    4.25   3      5    18.0    27.0  1.11   1.12    ⋯
# 11  1.06  1.02   2.34    4.75   3      5    12.0    11.0  1.05   1.05    ⋯
# ...

# %%
sd(na.exclude(discrim$psoda))
sd(na.exclude(discrim$pfries))
# Out:
# [1] 0.08868734
# [1] 0.1058813

# %%
library(foreign)
affairs <- read.dta("http://fmwww.bc.edu/ec-p/data/wooldridge/affairs.dta")
View(affairs)
# Out:
#     id   male age yrsmarr kids relig educ occup ratemarr naffairs affair vryhap
# 1     4  1    37  10.000  0    3     18   7     4         0       0      0
# 2     5  0    27   4.000  0    4     14   6     4         0       0      0
# 3     6  1    27   1.500  0    3     18   4     4         3       1      0
# 4    11  0    32  15.000  1    1     12   1     4         0       0      0
# 5    12  0    27   4.000  1    3     17   1     5         3       1      1
# 6    16  1    57  15.000  1    5     18   6     5         0       0      1
# 7    23  1    22   0.750  0    2     17   6     3         0       0      0
# 8    29  0    32   1.500  0    2     17   5     5         0       0      1
# 9    43  1    37  15.000  1    5     18   6     2         7       1      0
# 10   44  0    22   0.750  0    2     12   1     3         0       0      0
# 11   45  1    57  15.000  1    2     14   4     4         0       0      0
# ...
